# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline  
 
 
#data=yf.download('TSLA',start='2019-08-01', interval='1h',  end='2021-05-01',progress=False)[['Close']]
data=yf.download('TSLA',start='2021-02-07', interval='1h',  end='2021-05-01',progress=False)[['Close']]
  
data.plot(figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.head()
# Out:
#                  Close
# Date
# 2021-02-08  868.377075
# 2021-02-08  864.739990
# 2021-02-08  868.000000
# 2021-02-08  863.820007
# 2021-02-08  856.419983

# %%
data.shape
# Out:
# (406, 1)

# %%
type(data.values[0][0])
# Out:
# numpy.float64

# %%
cl = data.Close.astype('float32')
train = cl[0:int(len(cl)*0.80)]
scl = MinMaxScaler()
#Scale the data
scl.fit(train.values.reshape(-1,1))
cl =scl.transform(cl.values.reshape(-1,1))

#Create a function to process the data into lb observations look back slices
# and create the train test dataset (90-10)
def processData(data,lb):
    X,Y = [],[]
    for i in range(len(data)-lb-1):
        X.append(data[i:(i+lb),0])
        Y.append(data[(i+lb),0])
        #print(data[i:(i+lb)][9] == data[(i+lb)])
    return np.array(X),np.array(Y)
 
 
lb=10
X,y = processData(cl,lb)
X_train,X_test = X[:int(X.shape[0]*0.90)],X[int(X.shape[0]*0.90):]
y_train,y_test = y[:int(y.shape[0]*0.90)],y[int(y.shape[0]*0.90):]

# %%
#Build the model
model = tf.keras.models.Sequential()
#Output - 254
#input shape - 1 array bestående af 10 arrays (timeseries)
model.add(tf.keras.layers.LSTM(254,input_shape=(lb,1)))
model.add(tf.keras.layers.Dense(units=1))
model.compile(optimizer='adam',loss='mse')
 
#Reshape data for (Sample,Timestep,Features) 
X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],1))
X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],1))
 
#Fit model with history to check for overfitting
history = model.fit(X_train,y_train,epochs=100,validation_data=(X_test,y_test),shuffle=False)
 
model.summary()
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 60ms/step - loss: 0.2607 - val_loss: 0.0026
# Epoch 2/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 3/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0128 - val_loss: 0.0016
# Epoch 4/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 5/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0064 - val_loss: 0.0016
# Epoch 6/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 7/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 8/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 9/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0036 - val_loss: 0.0015
# Epoch 10/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 11/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 12/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 13/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 14/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 15/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 16/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 17/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 18/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0034 - val_loss: 0.0014
# Epoch 19/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 20/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 21/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 22/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0013
# Epoch 23/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 24/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 25/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 26/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 27/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 28/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 29/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0031 - val_loss: 0.0012
# Epoch 30/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 31/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 32/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 33/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 34/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 35/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 36/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0029 - val_loss: 0.0011
# Epoch 37/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 38/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 39/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 40/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 41/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 42/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 43/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 44/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 45/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0026 - val_loss: 0.0010
# Epoch 46/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 47/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 48/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 49/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0024 - val_loss: 9.9293e-04
# Epoch 50/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0024 - val_loss: 9.8403e-04
# Epoch 51/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0024 - val_loss: 9.7506e-04
# Epoch 52/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0023 - val_loss: 9.6622e-04
# Epoch 53/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0023 - val_loss: 9.5775e-04
# Epoch 54/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0023 - val_loss: 9.4966e-04
# Epoch 55/100
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0023 - val_loss: 9.4167e-04
# Epoch 56/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0022 - val_loss: 9.3342e-04
# Epoch 57/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0022 - val_loss: 9.2481e-04
# Epoch 58/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0022 - val_loss: 9.1616e-04
# Epoch 59/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0022 - val_loss: 9.0792e-04
# Epoch 60/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0021 - val_loss: 9.0024e-04
# Epoch 61/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 8.9277e-04
# Epoch 62/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 8.8489e-04
# Epoch 63/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0021 - val_loss: 8.7640e-04
# Epoch 64/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 8.6776e-04
# Epoch 65/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0020 - val_loss: 8.5971e-04
# Epoch 66/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 8.5248e-04
# Epoch 67/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0020 - val_loss: 8.4547e-04
# Epoch 68/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0020 - val_loss: 8.3778e-04
# Epoch 69/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 8.2931e-04
# Epoch 70/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 8.2098e-04
# Epoch 71/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 8.1369e-04
# Epoch 72/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 8.0740e-04
# Epoch 73/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 8.0092e-04
# Epoch 74/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0019 - val_loss: 7.9333e-04
# Epoch 75/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 7.8539e-04
# Epoch 76/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0018 - val_loss: 7.7842e-04
# Epoch 77/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0018 - val_loss: 7.7297e-04
# Epoch 78/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0018 - val_loss: 7.6785e-04
# Epoch 79/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0018 - val_loss: 7.6148e-04
# Epoch 80/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 7.5442e-04
# Epoch 81/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 7.4831e-04
# Epoch 82/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 7.4400e-04
# Epoch 83/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 7.4016e-04
# Epoch 84/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 7.3464e-04
# Epoch 85/100
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0017 - val_loss: 7.2841e-04
# Epoch 86/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 7.2333e-04
# Epoch 87/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 7.2038e-04
# Epoch 88/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 7.1716e-04
# Epoch 89/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 7.1171e-04
# Epoch 90/100
# 12/12 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 7.0603e-04
# Epoch 91/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 7.0220e-04
# Epoch 92/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 7.0057e-04
# Epoch 93/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 6.9663e-04
# Epoch 94/100
# 12/12 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 6.9089e-04
# Epoch 95/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0017 - val_loss: 6.8574e-04
# Epoch 96/100
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0017 - val_loss: 6.8427e-04
# Epoch 97/100
# 12/12 [==============================] - 0s 27ms/step - loss: 0.0016 - val_loss: 6.8238e-04
# Epoch 98/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.0016 - val_loss: 6.7692e-04
# Epoch 99/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0016 - val_loss: 6.7078e-04
# Epoch 100/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0016 - val_loss: 6.6817e-04
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 254)               260096
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 255
# =================================================================
# Total params: 260,351
# Trainable params: 260,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(12,8))

Xt = model.predict(X_train)
plt.plot(scl.inverse_transform(y_train.reshape(-1,1)), label="Actual")
plt.plot(scl.inverse_transform(Xt), label="Predicted")
plt.legend()
plt.title("Train Dataset")
# Out:
# Text(0.5, 1.0, 'Train Dataset')

# %%
plt.figure(figsize=(12,8))
print(X_test.shape)
Xt = model.predict(X_test)
plt.plot(scl.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.plot(scl.inverse_transform(Xt), label="Predicted")
plt.legend()
plt.title("Test Dataset")
# Out:
# (40, 10, 1)
# Text(0.5, 1.0, 'Test Dataset')

# %%
model.save('./lstm_stock_prediction')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./lstm_stock_prediction/assets
# INFO:tensorflow:Assets written to: ./lstm_stock_prediction/assets

# %%
#def predictFuture(n, timeseries):
# Out:
# [[[0.596393  ]
#   [0.61305606]
#   [0.60871947]
#   [0.5958334 ]
#   [0.59962595]
#   [0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]]
#
#  [[0.61305606]
#   [0.60871947]
#   [0.5958334 ]
#   [0.59962595]
#   [0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]]
#
#  [[0.60871947]
#   [0.5958334 ]
#   [0.59962595]
#   [0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]]
#
#  [[0.5958334 ]
#   [0.59962595]
#   [0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]]
#
#  [[0.59962595]
#   [0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]]
#
#  [[0.58451736]
#   [0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]]
#
#  [[0.5591184 ]
#   [0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]]
#
#  [[0.53884447]
#   [0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]]
#
#  [[0.53804076]
#   [0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]]
#
#  [[0.5729214 ]
#   [0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]]
#
#  [[0.5833515 ]
#   [0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]]
#
#  [[0.57405627]
#   [0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]]
#
#  [[0.57932556]
#   [0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]]
#
#  [[0.56000435]
#   [0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]]
#
#  [[0.568097  ]
#   [0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]]
#
#  [[0.5679475 ]
#   [0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]
#   [0.519704  ]]
#
#  [[0.5957564 ]
#   [0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]
#   [0.519704  ]
#   [0.5176469 ]]
#
#  [[0.59818065]
#   [0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]
#   [0.519704  ]
#   [0.5176469 ]
#   [0.5097817 ]]
#
#  [[0.59542954]
#   [0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]
#   [0.519704  ]
#   [0.5176469 ]
#   [0.5097817 ]
#   [0.5058645 ]]
#
#  [[0.58908737]
#   [0.59051716]
#   [0.59342396]
#   [0.59468305]
#   [0.5026549 ]
#   [0.519704  ]
#   [0.5176469 ]
#   [0.5097817 ]
#   [0.5058645 ]
#   [0.50241387]]]

# %%
def predictFuture(values:np.ndarray, num_days:int, model:tf.keras.models.Sequential, roll_function) -> []:
    """
    Makes a prediction for the next [num_days] days based on the [values].
    values - a numpy ndarray containing the initial values, e.g. the last 10 days of stock quotes.
    col_range - a list indicating the column names in values, a prediction should be made from, e.g. 1-11.
    num_days - the number of days of the predicition.
    lr - a sklearn LinearRegression object for making the predictions.
    roll_function - a lambda method to shift each value forward in the values ndarray, as to make room for the predicted value.
    """
    
    predictions = []    
    for i in range(0, num_days):
        prediction = model.predict(np.array([values]));
        predictions.append(prediction[0])
        values = roll_function(values)
        values[len(values)-1] = prediction
    
    return predictions
    
predictions = predictFuture(X_test[19], 300, model, lambda x: np.roll(x, -1, 0))
plt.plot(scl.inverse_transform(y_test.reshape(-1,1)), label="Actual")
plt.plot(scl.inverse_transform(Xt), label="Predicted")
plt.plot(scl.inverse_transform(predictions), label="Real Prediction")
plt.legend()
plt.title("Test Dataset")
# Out:
# Text(0.5, 1.0, 'Test Dataset')
